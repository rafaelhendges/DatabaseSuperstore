# %% [markdown]
# <a href="https://colab.research.google.com/github/rafaelhendges/DatabaseSuperstore/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.set_style("whitegrid")

# %%
df = pd.read_csv("Sample - Superstore.csv")

# %%
print(df.columns)
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country/Region', 'City',
#        'State/Province', 'Postal Code', 'Region', 'Product ID', 'Category',
#        'Sub-Category', 'Product Name', 'Sales', 'Quantity', 'Discount',
#        'Profit'],
#       dtype='object')

# %%
# Verificar e tratar valores nulos
print("\nQuantidade de valores nulos por coluna:")
print(df.isnull().sum())
# Out:
# Quantidade de valores nulos por coluna:
# Row ID            0
# Order ID          0
# Order Date        0
# Ship Date         0
# Ship Mode         0
# Customer ID       0
# Customer Name     0
# Segment           0
# Country/Region    0
# City              0
# State/Province    0
# Postal Code       0
# Region            0
# Product ID        0
# Category          0
# Sub-Category      0
# Product Name      0
# Sales             0
# Quantity          0
# Discount          0
# Profit            0
# dtype: int64

# %%
# Excluir colunas ou linhas com valores nulos
df = df.dropna()

# %%
df = df.drop_duplicates()

# %%
print("\nDados após limpeza:")
print(df.info())
# Out:
# Dados após limpeza:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10194 entries, 0 to 10193
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Row ID          10194 non-null  int64
#  1   Order ID        10194 non-null  object
#  2   Order Date      10194 non-null  object
#  3   Ship Date       10194 non-null  object
#  4   Ship Mode       10194 non-null  object
#  5   Customer ID     10194 non-null  object
#  6   Customer Name   10194 non-null  object
#  7   Segment         10194 non-null  object
#  8   Country/Region  10194 non-null  object
#  9   City            10194 non-null  object
#  10  State/Province  10194 non-null  object
#  11  Postal Code     10194 non-null  object
#  12  Region          10194 non-null  object
#  13  Product ID      10194 non-null  object
#  14  Category        10194 non-null  object
#  15  Sub-Category    10194 non-null  object
#  16  Product Name    10194 non-null  object
#  17  Sales           10194 non-null  float64
#  18  Quantity        10194 non-null  int64
#  19  Discount        10194 non-null  float64
#  20  Profit          10194 non-null  float64
# dtypes: float64(3), int64(2), object(16)
# memory usage: 1.6+ MB
# None

# %%
categorical_columns = df.select_dtypes(include=['object']).columns
print("\nColunas categóricas:")
print(categorical_columns)

df_encoded = pd.get_dummies(df, columns=categorical_columns, drop_first=True)

print("\nDados após One-Hot Encoding:")
print(df_encoded.head())
# Out:
# Colunas categóricas:
# Index(['Order ID', 'Order Date', 'Ship Date', 'Ship Mode', 'Customer ID',
#        'Customer Name', 'Segment', 'Country/Region', 'City', 'State/Province',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name'],
#       dtype='object')
#
# Dados após One-Hot Encoding:
#    Row ID    Sales  Quantity  Discount   Profit  Order ID_CA-2021-107153  \
# 0       1   16.448         2       0.2   5.5512                    False
# 1       2    3.540         2       0.8  -5.4870                    False
# 2       3   11.784         3       0.2   4.2717                    False
# 3       4  272.736         3       0.2 -64.7748                    False
# 4       5   19.536         3       0.2   4.8840                    False
#
#    Order ID_CA-2021-115238  Order ID_CA-2021-115777  Order ID_CA-2021-117964  \
# 0                    False                    False                    False
# 1                    False                    False                    False
# 2                    False                    False                    False
# 3                    False                    False                    False
# 4                    False                    False                    False
#
#    Order ID_CA-2021-119508  ...  \
# 0                    False  ...
# 1                    False  ...
# 2                    False  ...
# 3                    False  ...
# 4                    False  ...
#
#    Product Name_Zebra ZM400 Thermal Label Printer  \
# 0                                           False
# 1                                           False
# 2                                           False
# 3                                           False
# 4                                           False
#
#    Product Name_Zebra Zazzle Fluorescent Highlighters  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Product Name_Zipper Ring Binder Pockets  \
# 0                                    False
# 1                                    False
# 2                                    False
# 3                                    False
# 4                                    False
#
#    Product Name_i.Sound Portable Power - 8000 mAh  \
# 0                                           False
# 1                                           False
# 2                                           False
# 3                                           False
# 4                                           False
#
#    Product Name_iHome FM Clock Radio with Lightning Dock  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Product Name_iKross Bluetooth Portable Keyboard + Cell Phone Stand Holder + Brush for Apple iPhone 5S 5C 5, 4S 4  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Product Name_iOttie HLCRIO102 Car Mount  Product Name_iOttie XL Car Mount  \
# 0                                    False                             False
# 1                                    False                             False
# 2                                    False                             False
# 3                                    False                             False
# 4                                    False                             False
#
#    Product Name_invisibleSHIELD by ZAGG Smudge-Free Screen Protector  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Product Name_netTALK DUO VoIP Telephone Service
# 0                                            False
# 1                                            False
# 2                                            False
# 3                                            False
# 4                                            False
#
# [5 rows x 14283 columns]

# %%
# Tentar converter a coluna 'Order Date' para datetime
df['Order Date'] = pd.to_datetime(df['Order Date'], format='%d-%m-%Y', errors='coerce')

# %%
print("\nPrimeiras linhas após conversão da coluna 'Order Date':")
print(df[['Order Date']].head())

#variaável ano
df['Year'] = df['Order Date'].dt.year

print("\nDados com a nova variável 'Year':")
print(df.head())
# Out:
# Primeiras linhas após conversão da coluna 'Order Date':
#   Order Date
# 0 2021-01-03
# 1 2021-01-04
# 2 2021-01-04
# 3 2021-01-04
# 4 2021-01-05
#
# Dados com a nova variável 'Year':
#    Row ID        Order ID Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  US-2021-103800 2021-01-03  07-01-2021  Standard Class    DP-13000
# 1       2  US-2021-112326 2021-01-04  08-01-2021  Standard Class    PO-19195
# 2       3  US-2021-112326 2021-01-04  08-01-2021  Standard Class    PO-19195
# 3       4  US-2021-112326 2021-01-04  08-01-2021  Standard Class    PO-19195
# 4       5  US-2021-141817 2021-01-05  12-01-2021  Standard Class    MB-18085
#
#    Customer Name      Segment Country/Region          City  ...  \
# 0  Darren Powers     Consumer  United States       Houston  ...
# 1  Phillina Ober  Home Office  United States    Naperville  ...
# 2  Phillina Ober  Home Office  United States    Naperville  ...
# 3  Phillina Ober  Home Office  United States    Naperville  ...
# 4     Mick Brown     Consumer  United States  Philadelphia  ...
#
#         Product ID         Category Sub-Category  \
# 0  OFF-PA-10000174  Office Supplies        Paper
# 1  OFF-BI-10004094  Office Supplies      Binders
# 2  OFF-LA-10003223  Office Supplies       Labels
# 3  OFF-ST-10002743  Office Supplies      Storage
# 4  OFF-AR-10003478  Office Supplies          Art
#
#                                         Product Name    Sales Quantity  \
# 0  Message Book, Wirebound, Four 5 1/2" X 4" Form...   16.448        2
# 1         GBC Standard Plastic Binding Systems Combs    3.540        2
# 2                                          Avery 508   11.784        3
# 3                      SAFCO Boltless Steel Shelving  272.736        3
# 4  Avery Hi-Liter EverBold Pen Style Fluorescent ...   19.536        3
#
#   Discount   Profit  Cluster  Year
# 0      0.2   5.5512        2  2021
# 1      0.8  -5.4870        2  2021
# 2      0.2   4.2717        2  2021
# 3      0.2 -64.7748        2  2021
# 4      0.2   4.8840        2  2021
#
# [5 rows x 23 columns]

# %%
print("\nQuantidade de amostras e variáveis:")
print(df.shape)
# Out:
# Quantidade de amostras e variáveis:
# (10194, 21)

# %%
# Medidas de tendência central
print("\nMedidas de tendência central:")
print(df.describe())

numeric_df = df.select_dtypes(include=['float64', 'int64'])

print("\nCorrelação entre variáveis numéricas:")
print(numeric_df.corr())
# Out:
# Medidas de tendência central:
#              Row ID                     Order Date         Sales  \
# count  10194.000000                          10194  10194.000000
# mean    5097.500000  2023-04-30 00:15:40.788699136    228.225854
# min        1.000000            2021-01-03 00:00:00      0.444000
# 25%     2549.250000            2022-05-14 00:00:00     17.220000
# 50%     5097.500000            2023-06-25 00:00:00     53.910000
# 75%     7645.750000            2024-05-14 00:00:00    209.500000
# max    10194.000000            2024-12-30 00:00:00  22638.480000
# std     2942.898656                            NaN    619.906839
#
#            Quantity      Discount        Profit
# count  10194.000000  10194.000000  10194.000000
# mean       3.791838      0.155385     28.673417
# min        1.000000      0.000000  -6599.978000
# 25%        2.000000      0.000000      1.760800
# 50%        3.000000      0.200000      8.690000
# 75%        5.000000      0.200000     29.297925
# max       14.000000      0.800000   8399.976000
# std        2.228317      0.206249    232.465115
#
# Correlação entre variáveis numéricas:
#             Row ID     Sales  Quantity  Discount    Profit
# Row ID    1.000000 -0.008958  0.000502 -0.001474  0.003022
# Sales    -0.008958  1.000000  0.198457 -0.027756  0.481460
# Quantity  0.000502  0.198457  1.000000  0.007475  0.066145
# Discount -0.001474 -0.027756  0.007475  1.000000 -0.218882
# Profit    0.003022  0.481460  0.066145 -0.218882  1.000000

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Gerando histogramas para visualizar a distribuição das variáveis numéricas
df.hist(figsize=(10, 8))
plt.suptitle('Distribuição das Variáveis Numéricas')
plt.show()

# Criando um boxplot para verificar a presença de outliers nas variáveis numéricas
plt.figure(figsize=(10, 6))
sns.boxplot(data=df.select_dtypes(include=['float64', 'int64']))
plt.title('Boxplot das Variáveis Numéricas')
plt.show()

# Criando um gráfico de dispersão para analisar a relação entre 'Sales' e 'Profit'
plt.figure(figsize=(8, 6))
sns.scatterplot(x='Sales', y='Profit', data=df)
plt.title('Correlação entre Sales e Profit')
plt.show()

# Exibindo um gráfico de barras para visualizar a distribuição das categorias em 'Category'
plt.figure(figsize=(8, 6))
sns.countplot(x='Category', data=df)
plt.title('Distribuição por Categoria')
plt.show()

# %%
# Identificação de outliers com boxplot
sns.boxplot(x=df['Sales'])
plt.title('Identificação de outliers para a variável Sales')
plt.show()

# Tratamento de outliers
Q1 = df['Sales'].quantile(0.25)
Q3 = df['Sales'].quantile(0.75)
IQR = Q3 - Q1
df = df[(df['Sales'] >= (Q1 - 1.5 * IQR)) & (df['Sales'] <= (Q3 + 1.5 * IQR))]

# %%
from sklearn.preprocessing import StandardScaler, MinMaxScaler

# Padronizar os dados (Z-Score)
scaler = StandardScaler()
df_scaled = df.copy()
df_scaled[df.select_dtypes(include=['float64', 'int64']).columns] = scaler.fit_transform(df.select_dtypes(include=['float64', 'int64']))

# Ou normalizar os dados (0-1)
scaler = MinMaxScaler()
df_normalized = df.copy()
df_normalized[df.select_dtypes(include=['float64', 'int64']).columns] = scaler.fit_transform(df.select_dtypes(include=['float64', 'int64']))

print("\nDados padronizados:")
print(df_scaled.head())
# Out:
# Dados padronizados:
#      Row ID        Order ID Order Date   Ship Date       Ship Mode  \
# 0 -1.739175  US-2021-103800 2021-01-03  07-01-2021  Standard Class
# 1 -1.738835  US-2021-112326 2021-01-04  08-01-2021  Standard Class
# 2 -1.738495  US-2021-112326 2021-01-04  08-01-2021  Standard Class
# 3 -1.738155  US-2021-112326 2021-01-04  08-01-2021  Standard Class
# 4 -1.737815  US-2021-141817 2021-01-05  12-01-2021  Standard Class
#
#   Customer ID  Customer Name      Segment Country/Region          City  ...  \
# 0    DP-13000  Darren Powers     Consumer  United States       Houston  ...
# 1    PO-19195  Phillina Ober  Home Office  United States    Naperville  ...
# 2    PO-19195  Phillina Ober  Home Office  United States    Naperville  ...
# 3    PO-19195  Phillina Ober  Home Office  United States    Naperville  ...
# 4    MB-18085     Mick Brown     Consumer  United States  Philadelphia  ...
#
#   Postal Code   Region       Product ID         Category Sub-Category  \
# 0       77095  Central  OFF-PA-10000174  Office Supplies        Paper
# 1       60540  Central  OFF-BI-10004094  Office Supplies      Binders
# 2       60540  Central  OFF-LA-10003223  Office Supplies       Labels
# 3       60540  Central  OFF-ST-10002743  Office Supplies      Storage
# 4       19143     East  OFF-AR-10003478  Office Supplies          Art
#
#                                         Product Name     Sales  Quantity  \
# 0  Message Book, Wirebound, Four 5 1/2" X 4" Form... -0.667988 -0.755701
# 1         GBC Standard Plastic Binding Systems Combs -0.781448 -0.755701
# 2                                          Avery 508 -0.708984 -0.287332
# 3                      SAFCO Boltless Steel Shelving  1.584743 -0.287332
# 4  Avery Hi-Liter EverBold Pen Style Fluorescent ... -0.640845 -0.287332
#
#    Discount    Profit
# 0  0.204969 -0.117687
# 1  3.044213 -0.343552
# 2  0.204969 -0.143869
# 3  0.204969 -1.556705
# 4  0.204969 -0.131340
#
# [5 rows x 21 columns]

# %%
from sklearn.cluster import KMeans

# Selecionar as variáveis numéricas para clustering
X = df.select_dtypes(include=['float64', 'int64'])

# Realizar o clustering com KMeans (escolher o número de clusters, por exemplo 3)
kmeans = KMeans(n_clusters=3, random_state=42)
df['Cluster'] = kmeans.fit_predict(X)

# Visualizar os clusters
plt.figure(figsize=(8, 6))
sns.scatterplot(x='Sales', y='Profit', hue='Cluster', data=df, palette='viridis')
plt.title('Clusters baseados em Sales e Profit')
plt.show()
